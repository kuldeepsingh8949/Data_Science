# %%
import pandas as pd

# %%
df = pd.read_csv("laptopPrice.csv")   # read the dataset
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.tail()     # bottom 5 values
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df.duplicated()     # checek duplicacy
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.sum()
# Out:
# brand                ASUSLenovoLenovoASUSASUSASUSASUSASUSLenovoacer...
# processor_brand      IntelIntelIntelIntelIntelIntelIntelIntelIntelA...
# processor_name       Core i3Core i3Core i3Core i5Celeron DualCelero...
# processor_gnrtn      10th10th10th10thNot AvailableNot AvailableNot ...
# ram_gb               4 GB4 GB4 GB8 GB4 GB4 GB4 GB8 GB4 GB4 GB4 GB4 ...
# ram_type             DDR4DDR4DDR4DDR4DDR4DDR4DDR4DDR4DDR4DDR4DDR4DD...
# ssd                  0 GB0 GB0 GB512 GB0 GB0 GB0 GB0 GB0 GB0 GB0 GB...
# hdd                  1024 GB1024 GB1024 GB0 GB512 GB512 GB512 GB102...
# os                   WindowsWindowsWindowsWindowsWindowsWindowsWind...
# os_bit               64-bit64-bit64-bit32-bit64-bit64-bit32-bit32-b...
# graphic_card_gb      0 GB0 GB0 GB2 GB0 GB0 GB0 GB2 GB0 GB4 GB6 GB4 ...
# weight               CasualCasualCasualCasualCasualCasualCasualCasu...
# warranty             No warrantyNo warrantyNo warrantyNo warrantyNo...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.describe()    # give the mean max or average of numeric values
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
num_column = df.select_dtypes(exclude="O")  ## numerical column

# %%
num_column
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]

# %%
char_column = df.select_dtypes(include="O")  # char column

# %%
char_column
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
char_column.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice   rating
# 0          No       No  2 stars
# ...

# %%
char_column["brand"].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
char_column["brand"].nunique()
# Out:
# 8

# %%
char_column["processor_brand"].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
char_column["processor_gnrtn"].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
char_column["processor_name"].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
char_column["ram_type"].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
char_column["ssd"].nunique()
# Out:
# 7

# %%
df["brand"].value_counts()   ## find all values of column
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
apple = df[df["brand"]=="APPLE"]
apple
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
asus = df[df["brand"]=="ASUS"]
asus
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
m1_chip = [apple["processor_brand"]=="m1"]
m1_chip
# Out:
# [309    False
#  310    False
#  407    False
#  408    False
#  599    False
#  600    False
#  601    False
#  602    False
#  603    False
#  604    False
#  605    False
#  606    False
#  607    False
#  608    False
#  609    False
#  610    False
#  611    False
#  612    False
#  613    False
#  614    False
#  615    False
#  616    False
#  617    False
#  618    False
#  619    False
#  620    False
#  621    False
#  622    False
#  Name: processor_brand, dtype: bool]

# %%
maximum = apple["Price"]
maximum
# Out:
# 309    159990
# 310    172090
# 407    179990
# 408    179990
# 599     85990
# 600    112990
# 601    104990
# 602    112990
# 603    132990
# 604    104990
# 605     85990
# 606    149990
# 607    125990
# 608    103990
# 609    101990
# 610    104990
# 611    131990
# 612    128990
# 613    184990
# 614    225990
# 615    124990
# 616    104990
# 617    149990
# 618    169990
# 619    225990
# 620    243990
# 621    309990
# 622    225990
# Name: Price, dtype: int64

# %%
maximum.max()
# Out:
# 309990

# %%
best_lap = apple[apple["processor_brand"]=="Intel"]
best_lap
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
#
#          ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 309   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 310   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 407  1024 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 408  1024 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# 309       No  159990  4 stars                 32                  5
# 310       No  172090  4 stars                108                 13
# ...

# %%
apple_ram = best_lap[best_lap["ram_gb"]=="8 GB"]
apple_ram
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
#
#         ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 309  512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 310  512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# 309       No  159990  4 stars                 32                  5
# 310       No  172090  4 stars                108                 13

# %%
finding = apple_ram[apple_ram["Price"]<100000]
finding
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
as1 = asus[asus["processor_brand"]=="Intel"]
as1
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 630  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 632  ASUS           Intel   Pentium Quad   Not Available   4 GB   LPDDR4
# 633  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 634  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 635  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
as2 = as1[as1["ram_type"]=="DDR4"]
as2
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 627  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 630  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 633  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 634  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 635  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
as3 = as2[as2["processor_gnrtn"]=="10th"]
as3.head()
# Out:
#    brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3   ASUS           Intel        Core i5            10th   8 GB     DDR4
# 7   ASUS           Intel        Core i5            10th   8 GB     DDR4
# 27  ASUS           Intel        Core i3            10th   8 GB     DDR4
# 60  ASUS           Intel        Core i3            10th   4 GB     DDR4
#
#        ssd      hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 0     0 GB  1024 GB  Windows  64-bit            0 GB      Casual  No warranty
# 3   512 GB     0 GB  Windows  32-bit            2 GB      Casual  No warranty
# 7     0 GB  1024 GB  Windows  32-bit            2 GB      Casual  No warranty
# 27  256 GB     0 GB  Windows  64-bit            0 GB  ThinNlight  No warranty
# 60  256 GB     0 GB  Windows  64-bit            0 GB      Casual       1 year
#
# ...

# %%
df.duplicated().sum()   # total duplicate values
# Out:
# 21

# %%
df.drop_duplicates(inplace=True)     ## drop all duplicate values

# %%
df.isnull().sum()    # null values
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
acer = df[df["brand"]=="acer"]
acer.head()
# Out:
#    brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 9   acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 10  acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 11  acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 31  acer           Intel        Core i3            11th   8 GB     DDR4
# 64  acer           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#        ssd     hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 9     0 GB  512 GB  Windows  32-bit            4 GB      Casual  No warranty
# 10    0 GB  512 GB  Windows  32-bit            6 GB      Casual  No warranty
# 11    0 GB  512 GB  Windows  32-bit            4 GB      Casual  No warranty
# 31  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
# 64    0 GB  512 GB  Windows  32-bit            0 GB      Casual  No warranty
#
# ...

# %%
ac1 = acer[(acer["graphic_card_gb"]=="4 GB")&(acer["ram_gb"]=="8 GB")&(acer["ssd"]=="512 GB")&(acer["os"]=="Windows")]
ac1
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 325  acer           Intel        Core i5             8th   8 GB     DDR4
#
#         ssd   hdd       os  os_bit graphic_card_gb  weight warranty  \
# 325  512 GB  0 GB  Windows  64-bit            4 GB  Casual   1 year
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 325          No       No  99500  3 stars                  0                  0

# %%
x = df.drop('Price',axis=1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Train data:", x_train)
print("Test data:",x_test)
# Out:
# Train data:       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 442    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 598    ASUS           Intel        Core i7            10th  16 GB  LPDDR4X
# 452    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 696    DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 339    ASUS           Intel        Core i5            11th   8 GB  LPDDR4X
# ..      ...             ...            ...             ...    ...      ...
# 73   Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 108    DELL           Intel        Core i3            11th   8 GB     DDR4
# 275  Lenovo           Intel        Core i5            10th   8 GB     DDR4
# 445    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 104    ASUS           Intel        Core i3            11th   8 GB     DDR4
#
# ...

# %%
x_train
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 442    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 598    ASUS           Intel        Core i7            10th  16 GB  LPDDR4X
# 452    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 696    DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 339    ASUS           Intel        Core i5            11th   8 GB  LPDDR4X
# ..      ...             ...            ...             ...    ...      ...
# 73   Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 108    DELL           Intel        Core i3            11th   8 GB     DDR4
# 275  Lenovo           Intel        Core i5            10th   8 GB     DDR4
# 445    ASUS           Intel        Core i5            11th   8 GB     DDR4
# 104    ASUS           Intel        Core i3            11th   8 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
y_train
# Out:
# 442     50990
# 598    146490
# 452     60190
# 696     59490
# 339     99990
#         ...
# 73      41990
# 108     60790
# 275     57500
# 445     52990
# 104     44990
# Name: Price, Length: 641, dtype: int64

# %%
x_test
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196    acer           Intel        Core i5   Not Available   8 GB     DDR5
# 299    ASUS           Intel        Core i5            11th   8 GB  LPDDR4X
# 171    DELL           Intel        Core i3            10th   8 GB     DDR4
# 537      HP           Intel        Core i7            10th  16 GB     DDR4
# 551     MSI           Intel        Core i7            11th  16 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 368    ASUS           Intel        Core i5            11th   8 GB  LPDDR4X
# 361      HP           Intel        Core i5            10th   8 GB     DDR4
# 446    DELL           Intel        Core i5            11th   8 GB     DDR4
# 767  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 529  Lenovo           Intel        Core i7            11th  16 GB     DDR4
#
# ...

# %%
y_test
# Out:
# 196     50990
# 299     72990
# 171     41490
# 537    144690
# 551    129990
#         ...
# 368    114990
# 361    126000
# 446     57990
# 767    106990
# 529    110999
# Name: Price, Length: 161, dtype: int64

# %%
from sklearn.linear_model import LinearRegression  # Algorithm import

# %%
lnr = LinearRegression()

# %%
asus
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
lnr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10772\323659375.py in ?()
# ----> 1 lnr.fit(x_train,y_train)
#
# c:\Users\kulde\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\kulde\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     605         n_jobs_ = self.n_jobs
#     606
#     607         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     608
# --> 609         X, y = self._validate_data(
#     610             X,
#     611             y,
# ...

# %%
lnr.score(x_train,y_train)* 100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10772\2224353191.py in ?()
# ----> 1 lnr.score(x_train,y_train)* 100
#
# c:\Users\kulde\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, sample_weight)
#     844         """
#     845
#     846         from .metrics import r2_score
#     847
# --> 848         y_pred = self.predict(X)
#     849         return r2_score(y, y_pred, sample_weight=sample_weight)
#
# c:\Users\kulde\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X)
#     302         -------
#     303         C : array, shape (n_samples,)
#     304             Returns predicted values.
#     305         """
# --> 306         return self._decision_function(X)
#
# c:\Users\kulde\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X)
#     282     def _decision_function(self, X):
# ...
